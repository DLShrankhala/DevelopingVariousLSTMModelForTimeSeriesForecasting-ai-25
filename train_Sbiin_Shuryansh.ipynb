# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import numpy as np

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
class Data:
    def __init__(self):
        self.dataframe = pd.DataFrame([])

    def read(self, file_name: str):
        self.dataframe = pd.read_csv(file_name)

    def clean_data(self):
        """Remove null values"""
        self.dataframe = self.dataframe.dropna()

    def print_head(self):
        """Print the first few rows of the dataframe"""
        print(self.dataframe.head())

    def print_description(self):
        """Print the statistical description of the dataframe"""
        print(self.dataframe.describe())

    def normalization(self):
        """Normalize the data frame, excluding the Date column"""
        self.scaler = MinMaxScaler(feature_range=(0, 1))
        numeric_columns = self.dataframe.select_dtypes(include=['float64', 'int64']).columns
        # Create a new DataFrame to store the normalized values
        normalized_data = self.scaler.fit_transform(self.dataframe[numeric_columns])
        # Update the original DataFrame with normalized values
        self.dataframe[numeric_columns] = normalized_data

    def visualize_open(self):
        """Plot graph for open stock values v/s date"""
        if 'Date' in self.dataframe.columns and 'Open' in self.dataframe.columns:
            self.dataframe['Date'] = pd.to_datetime(self.dataframe['Date'])
            plt.figure(figsize=(14, 7))
            plt.plot(self.dataframe['Date'], self.dataframe['Open'], label='Open Stock Prices')
            plt.title('Open Stock Prices Over Time')
            plt.xlabel('Date')
            plt.ylabel('Open Stock Price')
            plt.legend()
            plt.show()
        else:
            print("Date and/or Open column not found in the dataframe")

    def visualize_close(self):
        """Plot graph for close stock values v/s date"""
        if 'Date' in self.dataframe.columns and 'Close' in self.dataframe.columns:
            self.dataframe['Date'] = pd.to_datetime(self.dataframe['Date'])
            plt.figure(figsize=(14, 7))
            plt.plot(self.dataframe['Date'], self.dataframe['Close'], label='Close Stock Prices')
            plt.title('Close Stock Prices Over Time')
            plt.xlabel('Date')
            plt.ylabel('Close Stock Price')
            plt.legend()
            plt.show()
        else:
            print("Date and/or Close column not found in the dataframe")

# %%
data = Data()

# %%
data.read('SBIN.NS.csv')

# %%
data.clean_data()

# %%
data.print_head()
data.print_description()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2019-05-31  354.350006  357.899994  344.649994  352.500000  331.788635
# 1  2019-06-03  352.350006  356.450012  349.649994  355.450012  334.565338
# 2  2019-06-04  354.000000  357.200012  351.399994  352.399994  331.694519
# 3  2019-06-06  349.000000  349.600006  335.899994  336.899994  317.105194
# 4  2019-06-07  337.000000  342.750000  336.000000  342.049988  321.952606
#
#      Volume
# 0  32588069
# 1  18380919
# 2  18130636
# 3  41941144
# 4  29739710
#               Open         High          Low        Close    Adj Close  \
# count  1236.000000  1236.000000  1236.000000  1236.000000  1236.000000
# mean    444.471360   449.609507   438.708980   444.116505   426.991310
# std     161.675055   162.631006   160.854066   161.809665   161.807725
# min     151.949997   153.199997   149.449997   150.850006   141.986725
# 25%     316.162506   321.925003   312.687492   317.449990   298.798027
# 50%     462.000000   468.899994   457.875000   462.524994   440.959565
# 75%     569.024994   574.000000   565.137482   568.624985   553.856186
# max     835.700012   841.250000   828.750000   833.700012   833.700012
#
#              Volume
# count  1.236000e+03
# mean   3.104837e+07
# std    2.567822e+07
# min    2.022528e+06
# 25%    1.396799e+07
# 50%    2.150688e+07
# 75%    4.088512e+07
# max    2.149557e+08

# %%
data.normalization()

# %%
data.visualize_open()

# %%
data.visualize_close()

# %%
class LSTMTrainer:
    def __init__(self, dataframe, scaler):
        self.dataframe = dataframe
        self.scaler = scaler

    def prepare_data_for_lstm(self, feature_col='Close', look_back=60):
        """Prepare data for LSTM by creating sequences"""
        data = self.dataframe[feature_col].values
        data = data.reshape(-1, 1)  # Reshape to (n_samples, 1)
        X, y = [], []
        for i in range(len(data) - look_back):
            X.append(data[i:i + look_back])
            y.append(data[i + look_back])
        X, y = np.array(X), np.array(y)
        # Split data while preserving the number of features
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
        return X_train, X_test, y_train, y_test.reshape(-1, 1)

    def build_and_train_lstm(self, feature_col='Close', look_back=60, epochs=100, batch_size=32):
        """Build and train the LSTM model"""
        X_train, X_test, y_train, y_test = self.prepare_data_for_lstm(feature_col, look_back)

        model = Sequential()
        model.add(LSTM(units=50, return_sequences=True, input_shape=(look_back, 1)))
        model.add(LSTM(units=50))
        model.add(Dense(1))

        model.compile(optimizer='adam', loss='mean_squared_error')

        model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))

        self.model = model
        self.X_test = X_test
        self.y_test = y_test


    def predict_and_plot(self):
        """Make predictions and plot the results"""
        predictions = self.model.predict(self.X_test)
        predictions = predictions.reshape(-1, 1)

        # Extract the 'Close' column from the original dataframe
        self.close_scaler = MinMaxScaler(feature_range=(0, 1))  # Create a new scaler for just the 'Close' column
        self.close_scaler.fit(self.dataframe['Close'].values.reshape(-1, 1))  # Fit the scaler to the 'Close' column

        # Inverse transform predictions using the scaler fitted on 'Close' column
        predictions = self.close_scaler.inverse_transform(predictions)
        # Inverse transform actual 'Close' values
        actual = self.close_scaler.inverse_transform(self.y_test)

        plt.figure(figsize=(14, 7))
        plt.plot(actual, label='Actual Stock Price')
        plt.plot(predictions, label='Predicted Stock Price')
        plt.title('Actual vs Predicted Stock Prices')
        plt.xlabel('Time')
        plt.ylabel('Stock Price')
        plt.legend()
        plt.show()


    def evaluate_model(self):
        """Calculates and prints evaluation metrics."""
        predictions = self.model.predict(self.X_test)
        predictions = self.close_scaler.inverse_transform(predictions)  # Assuming you're using the close_scaler
        actual = self.close_scaler.inverse_transform(self.y_test)

        mse = mean_squared_error(actual, predictions)
        rmse = np.sqrt(mse)
        mae = mean_absolute_error(actual, predictions)
        r2 = r2_score(actual, predictions)

        print(f"Mean Squared Error (MSE): {mse}")
        print(f"Root Mean Squared Error (RMSE): {rmse}")
        print(f"Mean Absolute Error (MAE): {mae}")
        print(f"R-squared (R2): {r2}")

# %%
trainer = LSTMTrainer(data.dataframe, data.scaler)

# %%
trainer.build_and_train_lstm(feature_col='Close', look_back=60, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 7s 117ms/step - loss: 0.0283 - val_loss: 0.0055
# Epoch 2/100
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0022 - val_loss: 0.0033
# Epoch 3/100
# 30/30 [==============================] - 2s 52ms/step - loss: 9.7439e-04 - val_loss: 0.0025
# Epoch 4/100
# 30/30 [==============================] - 2s 53ms/step - loss: 9.1511e-04 - val_loss: 0.0021
# Epoch 5/100
# 30/30 [==============================] - 2s 54ms/step - loss: 8.7749e-04 - val_loss: 0.0025
# Epoch 6/100
# 30/30 [==============================] - 2s 53ms/step - loss: 8.5975e-04 - val_loss: 0.0016
# Epoch 7/100
# 30/30 [==============================] - 2s 53ms/step - loss: 8.5659e-04 - val_loss: 0.0018
# Epoch 8/100
# 30/30 [==============================] - 2s 63ms/step - loss: 8.6675e-04 - val_loss: 0.0025
# Epoch 9/100
# 30/30 [==============================] - 3s 98ms/step - loss: 8.4512e-04 - val_loss: 0.0013
# Epoch 10/100
# 30/30 [==============================] - 2s 55ms/step - loss: 7.9348e-04 - val_loss: 0.0013
# Epoch 11/100
# 30/30 [==============================] - 2s 53ms/step - loss: 7.0740e-04 - val_loss: 0.0026
# Epoch 12/100
# 30/30 [==============================] - 2s 54ms/step - loss: 6.9437e-04 - val_loss: 0.0010
# Epoch 13/100
# 30/30 [==============================] - 2s 53ms/step - loss: 6.3410e-04 - val_loss: 0.0012
# Epoch 14/100
# 30/30 [==============================] - 2s 53ms/step - loss: 6.1588e-04 - val_loss: 0.0012
# Epoch 15/100
# 30/30 [==============================] - 2s 53ms/step - loss: 5.8434e-04 - val_loss: 0.0014
# Epoch 16/100
# 30/30 [==============================] - 3s 90ms/step - loss: 5.6880e-04 - val_loss: 0.0012
# Epoch 17/100
# 30/30 [==============================] - 2s 69ms/step - loss: 5.4315e-04 - val_loss: 9.1275e-04
# Epoch 18/100
# 30/30 [==============================] - 2s 53ms/step - loss: 5.2318e-04 - val_loss: 0.0013
# Epoch 19/100
# 30/30 [==============================] - 2s 53ms/step - loss: 4.9547e-04 - val_loss: 7.1657e-04
# Epoch 20/100
# 30/30 [==============================] - 2s 54ms/step - loss: 4.8088e-04 - val_loss: 0.0012
# Epoch 21/100
# 30/30 [==============================] - 2s 54ms/step - loss: 4.8579e-04 - val_loss: 6.9091e-04
# Epoch 22/100
# 30/30 [==============================] - 2s 53ms/step - loss: 4.9024e-04 - val_loss: 6.6906e-04
# Epoch 23/100
# 30/30 [==============================] - 2s 67ms/step - loss: 4.4015e-04 - val_loss: 7.8874e-04
# Epoch 24/100
# 30/30 [==============================] - 3s 94ms/step - loss: 4.1972e-04 - val_loss: 6.6622e-04
# Epoch 25/100
# 30/30 [==============================] - 2s 55ms/step - loss: 4.3162e-04 - val_loss: 0.0014
# Epoch 26/100
# 30/30 [==============================] - 2s 54ms/step - loss: 4.3686e-04 - val_loss: 6.0877e-04
# Epoch 27/100
# 30/30 [==============================] - 2s 53ms/step - loss: 4.2330e-04 - val_loss: 6.3669e-04
# Epoch 28/100
# 30/30 [==============================] - 2s 53ms/step - loss: 4.1426e-04 - val_loss: 9.5823e-04
# Epoch 29/100
# 30/30 [==============================] - 2s 53ms/step - loss: 4.1521e-04 - val_loss: 5.7494e-04
# Epoch 30/100
# 30/30 [==============================] - 2s 53ms/step - loss: 3.9974e-04 - val_loss: 0.0014
# Epoch 31/100
# 30/30 [==============================] - 2s 83ms/step - loss: 3.9695e-04 - val_loss: 5.0796e-04
# Epoch 32/100
# 30/30 [==============================] - 2s 81ms/step - loss: 3.8881e-04 - val_loss: 6.0841e-04
# Epoch 33/100
# 30/30 [==============================] - 2s 53ms/step - loss: 3.5122e-04 - val_loss: 5.1438e-04
# Epoch 34/100
# 30/30 [==============================] - 2s 54ms/step - loss: 3.4745e-04 - val_loss: 6.9792e-04
# Epoch 35/100
# 30/30 [==============================] - 2s 53ms/step - loss: 3.6533e-04 - val_loss: 5.5934e-04
# Epoch 36/100
# 30/30 [==============================] - 2s 53ms/step - loss: 3.3136e-04 - val_loss: 4.1476e-04
# Epoch 37/100
# 30/30 [==============================] - 2s 53ms/step - loss: 3.3096e-04 - val_loss: 4.2608e-04
# Epoch 38/100
# 30/30 [==============================] - 2s 54ms/step - loss: 3.0892e-04 - val_loss: 4.6796e-04
# Epoch 39/100
# 30/30 [==============================] - 3s 96ms/step - loss: 3.1370e-04 - val_loss: 4.5541e-04
# Epoch 40/100
# 30/30 [==============================] - 2s 69ms/step - loss: 3.1797e-04 - val_loss: 4.4679e-04
# Epoch 41/100
# 30/30 [==============================] - 2s 53ms/step - loss: 3.3954e-04 - val_loss: 7.4768e-04
# Epoch 42/100
# 30/30 [==============================] - 2s 53ms/step - loss: 3.1371e-04 - val_loss: 3.9014e-04
# Epoch 43/100
# 30/30 [==============================] - 2s 53ms/step - loss: 3.0379e-04 - val_loss: 4.0652e-04
# Epoch 44/100
# 30/30 [==============================] - 2s 53ms/step - loss: 2.9491e-04 - val_loss: 3.2871e-04
# Epoch 45/100
# 30/30 [==============================] - 2s 53ms/step - loss: 3.3236e-04 - val_loss: 4.4483e-04
# Epoch 46/100
# 30/30 [==============================] - 2s 62ms/step - loss: 3.1298e-04 - val_loss: 4.6930e-04
# Epoch 47/100
# 30/30 [==============================] - 3s 90ms/step - loss: 3.0189e-04 - val_loss: 4.0165e-04
# Epoch 48/100
# 30/30 [==============================] - 2s 53ms/step - loss: 2.8557e-04 - val_loss: 4.4256e-04
# Epoch 49/100
# 30/30 [==============================] - 2s 52ms/step - loss: 2.8225e-04 - val_loss: 3.6740e-04
# Epoch 50/100
# 30/30 [==============================] - 2s 53ms/step - loss: 2.6416e-04 - val_loss: 3.0165e-04
# Epoch 51/100
# 30/30 [==============================] - 2s 54ms/step - loss: 2.5916e-04 - val_loss: 5.1634e-04
# Epoch 52/100
# 30/30 [==============================] - 2s 53ms/step - loss: 2.5784e-04 - val_loss: 2.8320e-04
# Epoch 53/100
# 30/30 [==============================] - 2s 54ms/step - loss: 2.9591e-04 - val_loss: 8.1122e-04
# Epoch 54/100
# 30/30 [==============================] - 3s 86ms/step - loss: 3.1058e-04 - val_loss: 3.2098e-04
# Epoch 55/100
# 30/30 [==============================] - 2s 75ms/step - loss: 2.5947e-04 - val_loss: 2.7629e-04
# Epoch 56/100
# 30/30 [==============================] - 2s 53ms/step - loss: 2.5702e-04 - val_loss: 2.9568e-04
# Epoch 57/100
# 30/30 [==============================] - 2s 53ms/step - loss: 2.4126e-04 - val_loss: 3.6733e-04
# Epoch 58/100
# 30/30 [==============================] - 2s 54ms/step - loss: 2.4350e-04 - val_loss: 4.8396e-04
# Epoch 59/100
# 30/30 [==============================] - 2s 53ms/step - loss: 2.7274e-04 - val_loss: 2.5975e-04
# Epoch 60/100
# 30/30 [==============================] - 2s 53ms/step - loss: 2.2570e-04 - val_loss: 2.7343e-04
# Epoch 61/100
# 30/30 [==============================] - 2s 60ms/step - loss: 2.2821e-04 - val_loss: 2.9947e-04
# Epoch 62/100
# 30/30 [==============================] - 3s 109ms/step - loss: 2.1722e-04 - val_loss: 2.4913e-04
# Epoch 63/100
# 30/30 [==============================] - 2s 57ms/step - loss: 2.1578e-04 - val_loss: 2.5413e-04
# Epoch 64/100
# 30/30 [==============================] - 2s 53ms/step - loss: 2.1416e-04 - val_loss: 2.7997e-04
# Epoch 65/100
# 30/30 [==============================] - 2s 53ms/step - loss: 2.4817e-04 - val_loss: 2.4895e-04
# Epoch 66/100
# 30/30 [==============================] - 2s 53ms/step - loss: 2.3218e-04 - val_loss: 2.4172e-04
# Epoch 67/100
# 30/30 [==============================] - 2s 55ms/step - loss: 2.1750e-04 - val_loss: 6.9453e-04
# Epoch 68/100
# 30/30 [==============================] - 2s 53ms/step - loss: 2.1098e-04 - val_loss: 2.2766e-04
# Epoch 69/100
# 30/30 [==============================] - 2s 78ms/step - loss: 2.0352e-04 - val_loss: 4.5506e-04
# Epoch 70/100
# 30/30 [==============================] - 2s 80ms/step - loss: 1.9473e-04 - val_loss: 2.1975e-04
# Epoch 71/100
# 30/30 [==============================] - 2s 53ms/step - loss: 1.9428e-04 - val_loss: 2.5808e-04
# Epoch 72/100
# 30/30 [==============================] - 2s 53ms/step - loss: 1.9232e-04 - val_loss: 2.3389e-04
# Epoch 73/100
# 30/30 [==============================] - 2s 54ms/step - loss: 2.6727e-04 - val_loss: 2.2795e-04
# Epoch 74/100
# 30/30 [==============================] - 2s 53ms/step - loss: 1.8709e-04 - val_loss: 3.4587e-04
# Epoch 75/100
# 30/30 [==============================] - 2s 53ms/step - loss: 1.9714e-04 - val_loss: 2.3351e-04
# Epoch 76/100
# 30/30 [==============================] - 2s 60ms/step - loss: 1.9483e-04 - val_loss: 2.2046e-04
# Epoch 77/100
# 30/30 [==============================] - 3s 90ms/step - loss: 1.8065e-04 - val_loss: 2.1129e-04
# Epoch 78/100
# 30/30 [==============================] - 2s 55ms/step - loss: 1.8731e-04 - val_loss: 3.6785e-04
# Epoch 79/100
# 30/30 [==============================] - 2s 53ms/step - loss: 1.8481e-04 - val_loss: 2.8364e-04
# Epoch 80/100
# 30/30 [==============================] - 2s 53ms/step - loss: 1.8639e-04 - val_loss: 2.0001e-04
# Epoch 81/100
# 30/30 [==============================] - 2s 54ms/step - loss: 1.8542e-04 - val_loss: 0.0010
# Epoch 82/100
# 30/30 [==============================] - 2s 53ms/step - loss: 2.0388e-04 - val_loss: 4.5639e-04
# Epoch 83/100
# 30/30 [==============================] - 2s 53ms/step - loss: 1.7533e-04 - val_loss: 3.8429e-04
# Epoch 84/100
# 30/30 [==============================] - 2s 83ms/step - loss: 1.8830e-04 - val_loss: 4.4689e-04
# Epoch 85/100
# 30/30 [==============================] - 2s 80ms/step - loss: 2.3161e-04 - val_loss: 3.4153e-04
# Epoch 86/100
# 30/30 [==============================] - 2s 53ms/step - loss: 1.7636e-04 - val_loss: 4.5363e-04
# Epoch 87/100
# 30/30 [==============================] - 2s 54ms/step - loss: 1.7870e-04 - val_loss: 2.4140e-04
# Epoch 88/100
# 30/30 [==============================] - 2s 54ms/step - loss: 1.7023e-04 - val_loss: 2.7201e-04
# Epoch 89/100
# 30/30 [==============================] - 2s 54ms/step - loss: 1.6092e-04 - val_loss: 2.6207e-04
# Epoch 90/100
# 30/30 [==============================] - 2s 52ms/step - loss: 1.6871e-04 - val_loss: 2.0366e-04
# Epoch 91/100
# 30/30 [==============================] - 2s 56ms/step - loss: 1.6298e-04 - val_loss: 3.7194e-04
# Epoch 92/100
# 30/30 [==============================] - 3s 91ms/step - loss: 1.8286e-04 - val_loss: 5.5963e-04
# Epoch 93/100
# 30/30 [==============================] - 2s 59ms/step - loss: 1.9881e-04 - val_loss: 3.2554e-04
# Epoch 94/100
# 30/30 [==============================] - 2s 53ms/step - loss: 1.6975e-04 - val_loss: 2.0505e-04
# Epoch 95/100
# 30/30 [==============================] - 2s 52ms/step - loss: 1.5940e-04 - val_loss: 3.0440e-04
# Epoch 96/100
# 30/30 [==============================] - 2s 53ms/step - loss: 1.7391e-04 - val_loss: 2.0224e-04
# Epoch 97/100
# 30/30 [==============================] - 2s 53ms/step - loss: 1.6001e-04 - val_loss: 2.9554e-04
# Epoch 98/100
# 30/30 [==============================] - 2s 54ms/step - loss: 1.5084e-04 - val_loss: 1.8967e-04
# Epoch 99/100
# 30/30 [==============================] - 2s 74ms/step - loss: 1.5816e-04 - val_loss: 2.0574e-04
# Epoch 100/100
# 30/30 [==============================] - 3s 90ms/step - loss: 1.5221e-04 - val_loss: 3.3531e-04

# %%
trainer.predict_and_plot()
# Out:
# 8/8 [==============================] - 1s 15ms/step

# %%
trainer.evaluate_model()
# Out:
# 8/8 [==============================] - 0s 17ms/step
# Mean Squared Error (MSE): 0.0003353109501076354
# Root Mean Squared Error (RMSE): 0.018311497757082445
# Mean Absolute Error (MAE): 0.014036248828917314
# R-squared (R2): 0.9805958162744591
